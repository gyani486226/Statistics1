# %%
#2. What are the measures of central tendency, and when should you use each? Discuss the mean, median,
#and mode with examples and situations where each is appropriate.
hlo = [1,1, 2, 3, 4, 5, 6]
from scipy import stats
mean1 = np.mean(hlo)
mod1 = stats.mode(hlo)
med1 = np.median(hlo)
print(mean1)
print(mod1)
print(med1)
# Out:
# 3.142857142857143
# ModeResult(mode=1, count=2)
# 3.0

# %%
#Q12 Provide an example dataset, calculate both covariance and correlation, and interpret the results.
import seaborn as sns
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset("taxis")
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df.dtypes
# Out:
# pickup             datetime64[ns]
# dropoff            datetime64[ns]
# passengers                  int64
# distance                  float64
# fare                      float64
# tip                       float64
# tolls                     float64
# total                     float64
# color                      object
# payment                    object
# pickup_zone                object
# dropoff_zone               object
# pickup_borough             object
# dropoff_borough            object
# dtype: object

# %% [markdown]
# # covvariance

# %%
df.cov(numeric_only = True)
# covariance rangw can be anything
#between fare and passengers the covariance value is 0.106199 it means they are positive correlated
#between tolls and passengers the covariance is -0.004946 it means the are negative correleated (means tolls increase, passengers decreases)
# Out:
#             passengers   distance        fare        tip      tolls  \
# passengers    1.449058   0.043365    0.106199   0.062190  -0.004946
# distance      0.043365  14.652566   40.686031   4.242005   3.441533
# fare          0.106199  40.686031  133.444182  13.820539   9.961493
# tip           0.062190   4.242005   13.820539   5.995444   1.433341
# tolls        -0.004946   3.441533    9.961493   1.433341   2.002982
# total         0.261233  47.843057  155.502375  21.859332  13.357292
#
#                  total
# passengers    0.261233
# distance     47.843057
# fare        155.502375
# tip          21.859332
# tolls        13.357292
# total       190.869976

# %% [markdown]
# # correlation

# %%
# the range of correleation is (-1 t0 1), dimensionless quantity
df.corr(numeric_only = True)

# the correlation between distance and tip  is 0.45 i.e. if tip increases 45% chance distance is also increases
# Out:
#             passengers  distance      fare       tip     tolls     total
# passengers    1.000000  0.009411  0.007637  0.021099 -0.002903  0.015708
# distance      0.009411  1.000000  0.920108  0.452589  0.635267  0.904676
# fare          0.007637  0.920108  1.000000  0.488612  0.609307  0.974358
# tip           0.021099  0.452589  0.488612  1.000000  0.413619  0.646186
# tolls        -0.002903  0.635267  0.609307  0.413619  1.000000  0.683142
# total         0.015708  0.904676  0.974358  0.646186  0.683142  1.000000

# %%
corr= df.corr(numeric_only = True)
sns.heatmap(corr,  annot = True)
# Out:
# <Axes: >
